# %% [markdown]
# # Individual Income Tax Overview, Dependents, and Filing Status
#
# **Comprehensive Problems**
#
# McGraw Hill's Taxation of Individuals and Business Entities 2025
#
# Spilker, Ayers, Lewis, Weaver, Barrick, Robinson, Worsham

# %% [markdown]
# Tiffany is unmarried and has a 15-year-old qualifying child. Tiffany has determined her tax liability to be 3,525, and her employer has withheld 1,000 of federal taxes from her paycheck. Tiffany is allowed to claim a 2,000 child tax credit for her qualifying child. What amount of taxes will Tiffany owe (or what amount will she receive as a refund) when she files her tax return?

# %%
tax_liability = 3525
withholdings = -1000
child_tax_credit = -2000

tax_due_refund = tax_liability + child_tax_credit + withholdings
results = "Tax due" if tax_due_refund >= 0 else "Tax refund"

print(f"""
Tax liability:                        ${tax_liability:,.0f}
Child Tax Credit:                     {child_tax_credit:,.0f}
                                     -------
Tax liability before prepayments:      {tax_liability + child_tax_credit:,.0f}
Prepayments:                          {withholdings:,.0f}
                                     -------
{results}:                                ${tax_due_refund:,.0f}""")
# Out:
# Tax liability:                        $3,525
# Child Tax Credit:                     -2,000
#                                      -------
# Tax liability before prepayments:      1,525
# Prepayments:                          -1,000
#                                      -------
# Tax due:                                $525
